# %% [markdown]
# # SymPy

# %%
#pip install sympy

# %%
import sympy

# %%
import math

# %%
math.sqrt(8)
# Out:
# 2.8284271247461903

# %%
sympy.sqrt(8)
# Out:
# 2*sqrt(2)

# %% [markdown]
# **Function f**

# %%
from sympy import symbols

# %%
x = symbols('x')

# %%
f = 2 + 5*x

# %%
f
# Out:
# 5*x + 2

# %%
x,y = symbols('x,y')

# %%
g = 2*x + 5*y + 12

# %%
g
# Out:
# 2*x + 5*y + 12

# %%
g + x**2
# Out:
# x**2 + 2*x + 5*y + 12

# %%
g-12
# Out:
# 2*x + 5*y

# %%
x,y,z = symbols('x,y,z')

# %%
h = x**2 + 8*y - 25*z**2

# %%
h
# Out:
# x**2 + 8*y - 25*z**2

# %%
g
# Out:
# 2*x + 5*y + 12

# %%
g*x
# Out:
# x*(2*x + 5*y + 12)

# %%
from sympy import expand, factor

# %%
D = expand(g*x)

# %%
D
# Out:
# 2*x**2 + 5*x*y + 12*x

# %%
factor(D)
# Out:
# x*(2*x + 5*y + 12)

# %%
k = 8*x**3 + 25*x**2 + 16*x + 8

# %%
k
# Out:
# 8*x**3 + 25*x**2 + 16*x + 8

# %%
import diff
